# %% [markdown]
# <h1 style = "color : Brown">Variables & Keywords</h1>

# %% [markdown]
# A Python variable is a reserved memory location to store values. In other words, a variable in a python program gives data to the computer for processing.

# %%
a='hello world'

# %%
type(a)
# Out:
# str

# %%
my_age = 31

# %%
print(my_age)
# Out:
# 31

# %%
score = 89.4
score
# Out:
# 89.4

# %%
var = "Hello world, welcome to the class"

# %%
type(var)
# Out:
# str

# %%
var = 10

# %%
type(var)
# Out:
# int

# %%
string_var = "Hello world, welcome to the class"

# %%
print(string_var)
# Out:
# Hello world, welcome to the class

# %%
type(string_var)
# Out:
# str

# %%
a = "10.5"
type(a)
# Out:
# str

# %%
a = '10.5'
print(a)
print(type(a))
# Out:
# 10.5
# <class 'str'>

# %%
a='True'
print(type(a))
print(a)
# Out:
# <class 'str'>
# True

# %%
a=True
print(type(a))
print(a)
# Out:
# <class 'bool'>
# True

# %%
bool_var = "True"
print(bool_var)
print(type(bool_var))
# Out:
# True
# <class 'str'>

# %%
bool_var = True
print(bool_var)
print(type(bool_var))
# Out:
# True
# <class 'bool'>

# %%
5a = 10
# Out:
#   File "<ipython-input-24-62c1943fa328>", line 1
#     5a = 10
#      ^
# SyntaxError: invalid syntax

# %%
a=10
A=15

print(a)
print(A)
# Out:
# 10
# 15

# %%
name=2
Name=4

# %%
var = 10

# %%
float_var = 10.1

# %%
type(var)
# Out:
# int

# %%
type(float_var)
# Out:
# float

# %%
string1 = 'hello'
print(string1)
# Out:
# hello

# %%
string1
# Out:
# 'hello'

# %%
string2 = "hello 123 world"
print(string2)
# Out:
# hello 123 world

# %%
1new_var = 10
# Out:
#   File "<ipython-input-13-e637834d698f>", line 1
#     1new_var = 10
#            ^
# SyntaxError: invalid syntax

# %%
new_var = 10

# %%
print(new_var)
# Out:
# 10

# %%
name = 2
Name = 4
print(name)
print(Name)
# Out:
# 2
# 4

# %%
a=4
b=5
c=a+b
print(c)
# Out:
# 9

# %%
a=14
b=15
c=a+b
print(c)

# %%
def sum_fun(a,b):
    c=a+b
    return c

sum_fun(5,6)
# Out:
# 11

# %%
def func_sum(a,b):
    c=a+b
    return c


func_sum(4,5)
# Out:
# 9

# %%
func_sum(14,55)
# Out:
# 69

# %%
1name=5

# %%
a = 10

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(a)
#
# NameError: name 'a' is not defined

# %%
a = 10.1

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type(a)
#
# NameError: name 'a' is not defined

# %%
welcome_string = "Welcome to the Python course"

# %%
print(welcome_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(welcome_string)
#
# NameError: name 'welcome_string' is not defined

# %%
type(welcome_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 type(welcome_string)
#
# NameError: name 'welcome_string' is not defined

# %%
a = 10
b = 5
c = a+b
print(c)

# %%
def sum_function(a,b):
    c=a+b
    return c

# %%
sum_function(5,6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sum_function(5,6)
#
# NameError: name 'sum_function' is not defined

# %%
boolean_var = 'True'

# %%
type(boolean_var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 type(boolean_var)
#
# NameError: name 'boolean_var' is not defined

# %%
boolean_var = True

# %%
type(boolean_var)
# Out:
# bool

# %%
name = "satyajit pattnaik"
age = 31
gender = 'male'
address = 'hong kong'

# %%
#type() --> data type of the variable

type(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #type() --> data type of the variable
#       2
# ----> 3 type(age)
#
# NameError: name 'age' is not defined

# %%
def multiply(a,b):
    ans = a*b
    return ans
multiply(2,4)
# Out:
# 8

# %%
name = "Adarsh"
type(name)
# Out:
# str

# %%
def factorial(n):
    if n==0:
        return 1
    return n * factorial(n-1)
factorial(1)
# Out:
# 1

# %%
marks = 90.4
marks
# Out:
# float
